# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
graf_raw = pd.read_csv("311_Service_Requests_-_Graffiti_Removal.csv")
build_raw = pd.read_csv("311_Service_Requests_-_Vacant_and_Abandoned_Buildings_Reported.csv")
light_raw = pd.read_csv("311_Service_Requests_-_Alley_Lights_Out.csv")

# %%
# get rid of duplicates
graf_new = graf_raw[graf_raw['Status'].isin(['Completed', 'Open'])]
light_new = light_raw[light_raw['Status'].isin(['Completed', 'Open'])]

# %%
graf = graf_new[['Service Request Number', 'Type of Service Request', 'Creation Date', 'Completion Date', \
                 'What Type of Surface is the Graffiti on?',\
                'Community Area', 'Latitude','Longitude', 'Location']]

# %%
build = build_raw[['SERVICE REQUEST NUMBER','SERVICE REQUEST TYPE', 'DATE SERVICE REQUEST WAS RECEIVED', 'DATE SERVICE REQUEST WAS RECEIVED',\
                  'IS THE BUILDING CURRENTLY VACANT OR OCCUPIED?',\
                  'Community Area', 'LATITUDE', 'LONGITUDE', 'Location']]

# %%
light = light_new[['Service Request Number','Type of Service Request','Creation Date', 'Completion Date',\
                  'Status', \
                  'Community Area', 'Latitude', 'Longitude', 'Location']]

# %%
build.columns = graf.columns
light.columns = graf.columns
combinedf = pd.concat([graf, build, light], ignore_index=True)
combinedf.rename(columns={'What Type of Surface is the Graffiti on?':'Subtype'}, inplace=True)

# %%
combinedf[:10]
# Out:
#   Service Request Number Type of Service Request Creation Date  \
# 0            17-00001597        Graffiti Removal    01/01/2017
# 1            17-00001621        Graffiti Removal    01/01/2017
# 2            17-00001880        Graffiti Removal    01/01/2017
# 3            17-00003402        Graffiti Removal    01/01/2017
# 4            17-00003570        Graffiti Removal    01/01/2017
# 5            17-00003714        Graffiti Removal    01/01/2017
# 6            17-00003733        Graffiti Removal    01/01/2017
# 7            17-00003736        Graffiti Removal    01/01/2017
# 8            17-00003742        Graffiti Removal    01/01/2017
# 9            17-00003989        Graffiti Removal    01/01/2017
#
#   Completion Date                               Subtype  Community Area  \
# 0      01/04/2017                                 Glass             4.0
# 1      01/03/2017                 Other/Unknown Surface             4.0
# 2      01/03/2017                     Brick - Unpainted            14.0
# 3      01/03/2017  Cement (Sidewalk, Alley, Wall, Curb)            23.0
# 4      01/03/2017                       Metal - Painted            14.0
# 5      01/03/2017                       Aluminum Siding            29.0
# 6      01/03/2017                       Metal - Painted            30.0
# 7      01/03/2017                       Brick - Painted            30.0
# 8      01/03/2017                       Brick - Painted            30.0
# 9      01/03/2017                     Metal - Unpainted             6.0
#
#     Latitude  Longitude                                  Location
# 0  41.971233 -87.679113     (41.9712334555571, -87.6791128422349)
# 1  41.976268 -87.679265    (41.97626841305295, -87.6792651211414)
# 2  41.970310 -87.715486    (41.97031046080265, -87.7154855931689)
# 3  41.898989 -87.712918  (41.898988830409216, -87.71291800671355)
# 4  41.966730 -87.718350  (41.966730475911014, -87.71834995659019)
# 5  41.856267 -87.694205    (41.8562673296854, -87.69420508152886)
# 6  41.853708 -87.690872   (41.85370817247298, -87.69087191647458)
# 7  41.850122 -87.695547   (41.85012232500248, -87.69554656730969)
# 8  41.851445 -87.695289   (41.85144508733876, -87.69528872546177)
# 9  41.946047 -87.651714  (41.946046795928076, -87.65171416433947)
