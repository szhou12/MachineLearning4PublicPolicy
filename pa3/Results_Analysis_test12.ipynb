# %% [markdown]
# Results for test window = 12 months

# %%
import pandas as pd
import numpy as np
import eval_analysis as ea

# %%
# display full dataframe information 
pd.set_option('display.max_colwidth', -1)

# %%
METRICS = ["train_time", "test_time", "accuracy", "F1_score", "auc", 
           "p@1","p@2","p@5","p@10","p@20","p@30","p@50",
           "r@1","r@2","r@5","r@10","r@20","r@30","r@50"]

# %%
result_df = pd.read_csv("eval_results_1/classifiers_eval.csv", index_col=0)

# %%
ranking_dict = ea.all_rankings(result_df, METRICS)

# %%
# training time
train_time_ranking = ea.get_info(ranking_dict, 'train_time', ['model','parameters','train_time'])
train_time_ranking
# Out:
#    index model  \
# 0  2      DT
# 1  6      RF
# 2  0      BAG
# 3  5      NB
# 4  4      LR
# 5  3      KNN
# 6  1      BST
#
#                                                                                   parameters  \
# 0  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 10, 'max_features': 'sqrt'}
# 1  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 2  {'n_estimators': 5, 'max_samples': 0.65}
# 3  {}
# 4  {'penalty': 'l1', 'C': 1}
# 5  {'n_neighbors': 1, 'weights': 'distance', 'algorithm': 'kd_tree'}
# 6  {'n_estimators': 10, 'algorithm': 'SAMME'}
#
#    train_time
# 0  0.586452
# 1  0.660460
# 2  0.812236
# 3  0.941155
# 4  1.932698
# 5  2.242482
# 6  3.223455

# %%
# testing time
test_time_ranking = ea.get_info(ranking_dict, 'test_time', ['model','parameters','test_time'])
test_time_ranking
# Out:
#    index model  \
# 0  2      DT
# 1  6      RF
# 2  4      LR
# 3  0      BAG
# 4  1      BST
# 5  5      NB
# 6  3      KNN
#
#                                                                               parameters  \
# 0  {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 5, 'max_features': 'sqrt'}
# 1  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 10}
# 2  {'penalty': 'l1', 'C': 1}
# 3  {'n_estimators': 5, 'max_samples': 0.5}
# 4  {'n_estimators': 10, 'algorithm': 'SAMME'}
# 5  {}
# 6  {'n_neighbors': 1, 'weights': 'distance', 'algorithm': 'kd_tree'}
#
#    test_time
# 0  0.299813
# 1  0.307295
# 2  0.326775
# 3  0.380141
# 4  0.433016
# 5  0.517187
# 6  6.434297

# %%
# accuracy
acc_ranking = ea.get_info(ranking_dict, 'accuracy', ['model','parameters','accuracy'])
acc_ranking
# Out:
#    index model  \
# 0  6      RF
# 1  2      DT
# 2  4      LR
# 3  1      BST
# 4  5      NB
# 5  0      BAG
# 6  3      KNN
#
#                                                                                   parameters  \
# 0  {'max_features': 'log2', 'n_estimators': 100, 'max_depth': 50, 'min_samples_split': 10}
# 1  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'max_features': 'sqrt'}
# 2  {'penalty': 'l2', 'C': 0.1}
# 3  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 4  {}
# 5  {'n_estimators': 5, 'max_samples': 0.5}
# 6  {'n_neighbors': 10, 'weights': 'distance', 'algorithm': 'ball_tree'}
#
#    accuracy
# 0  0.936914
# 1  0.918449
# 2  0.909890
# 3  0.906502
# 4  0.853018
# 5  0.827631
# 6  0.754175

# %%
# F1 score
f1_ranking = ea.get_info(ranking_dict, 'F1_score', ['model','parameters','F1_score'])
f1_ranking
# Out:
#    index model  \
# 0  6      RF
# 1  2      DT
# 2  4      LR
# 3  1      BST
# 4  5      NB
# 5  0      BAG
# 6  3      KNN
#
#                                                                                   parameters  \
# 0  {'max_features': 'log2', 'n_estimators': 100, 'max_depth': 50, 'min_samples_split': 10}
# 1  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2, 'max_features': 'sqrt'}
# 2  {'penalty': 'l2', 'C': 0.1}
# 3  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 4  {}
# 5  {'n_estimators': 5, 'max_samples': 0.5}
# 6  {'n_neighbors': 10, 'weights': 'distance', 'algorithm': 'ball_tree'}
#
#    F1_score
# 0  0.956272
# 1  0.943606
# 2  0.937462
# 3  0.934127
# 4  0.900198
# 5  0.890862
# 6  0.842532

# %%
# AUC-ROC
auc_ranking = ea.get_info(ranking_dict, 'auc', ['model','parameters','auc'])
auc_ranking
# Out:
#    index model  \
# 0  6      RF
# 1  2      DT
# 2  1      BST
# 3  4      LR
# 4  5      NB
# 5  0      BAG
# 6  3      KNN
#
#                                                                                    parameters  \
# 0  {'max_features': 'sqrt', 'n_estimators': 100, 'max_depth': 50, 'min_samples_split': 2}
# 1  {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 10, 'max_features': 'log2'}
# 2  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 3  {'penalty': 'l1', 'C': 0.01}
# 4  {}
# 5  {'n_estimators': 5, 'max_samples': 0.5}
# 6  {'n_neighbors': 1, 'weights': 'distance', 'algorithm': 'ball_tree'}
#
#         auc
# 0  0.907289
# 1  0.892452
# 2  0.881952
# 3  0.879197
# 4  0.791799
# 5  0.709327
# 6  0.652945

# %%
# precision at 50%
p_at_50_ranking = ea.get_info(ranking_dict, 'p@50', ['model','parameters','p@50', 'train_time','r@50'])
p_at_50_ranking
# Out:
#    index model  \
# 0  2      DT
# 1  3      KNN
# 2  6      RF
# 3  1      BST
# 4  4      LR
# 5  0      BAG
# 6  5      NB
#
#                                                                                  parameters  \
# 0  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 5, 'max_features': 'sqrt'}
# 1  {'n_neighbors': 1, 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 2  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 3  {'n_estimators': 10, 'algorithm': 'SAMME'}
# 4  {'penalty': 'l1', 'C': 0.1}
# 5  {'n_estimators': 10, 'max_samples': 0.5}
# 6  {}
#
#        p@50  train_time      r@50
# 0  1.000000  0.624636    0.710657
# 1  1.000000  2.376567    0.710657
# 2  1.000000  0.660460    0.710657
# 3  0.961927  3.223455    0.683600
# 4  0.958059  2.067020    0.680852
# 5  0.943348  0.951025    0.670397
# 6  0.918464  0.941155    0.652713

# %%
# precision at 30%
p_at_30_ranking = ea.get_info(ranking_dict, 'p@30', ['model','parameters','p@30', 'train_time'])
p_at_30_ranking
# Out:
#    index model  \
# 0  2      DT
# 1  3      KNN
# 2  6      RF
# 3  1      BST
# 4  4      LR
# 5  5      NB
# 6  0      BAG
#
#                                                                                  parameters  \
# 0  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 5, 'max_features': 'sqrt'}
# 1  {'n_neighbors': 1, 'weights': 'distance', 'algorithm': 'auto'}
# 2  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 3  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 4  {'penalty': 'l1', 'C': 0.1}
# 5  {}
# 6  {'n_estimators': 10, 'max_samples': 0.5}
#
#        p@30  train_time
# 0  1.000000  0.624636
# 1  1.000000  2.310801
# 2  1.000000  0.660460
# 3  0.975989  49.490264
# 4  0.973425  2.067020
# 5  0.949388  0.941155
# 6  0.930555  0.951025

# %%
# precision at 20%
p_at_20_ranking = ea.get_info(ranking_dict, 'p@20', ['model','parameters','p@20', 'train_time'])
p_at_20_ranking
# Out:
#    index model  \
# 0  2      DT
# 1  3      KNN
# 2  6      RF
# 3  4      LR
# 4  1      BST
# 5  5      NB
# 6  0      BAG
#
#                                                                                 parameters  \
# 0  {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 5, 'max_features': 'sqrt'}
# 1  {'n_neighbors': 1, 'weights': 'uniform', 'algorithm': 'auto'}
# 2  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 3  {'penalty': 'l1', 'C': 0.1}
# 4  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 5  {}
# 6  {'n_estimators': 5, 'max_samples': 0.5}
#
#        p@20  train_time
# 0  1.000000  1.126271
# 1  1.000000  2.799279
# 2  1.000000  0.660460
# 3  0.985418  2.067020
# 4  0.981915  49.490264
# 5  0.976699  0.941155
# 6  0.970188  0.831823

# %%
# precision at 10%
p_at_10_ranking = ea.get_info(ranking_dict, 'p@10', ['model','parameters','p@10', 'train_time'])
p_at_10_ranking
# Out:
#    index model  \
# 0  1      BST
# 1  2      DT
# 2  3      KNN
# 3  4      LR
# 4  6      RF
# 5  5      NB
# 6  0      BAG
#
#                                                                               parameters  \
# 0  {'n_estimators': 10, 'algorithm': 'SAMME'}
# 1  {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 2, 'max_features': 'sqrt'}
# 2  {'n_neighbors': 1, 'weights': 'distance', 'algorithm': 'kd_tree'}
# 3  {'penalty': 'l1', 'C': 10}
# 4  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 5  {}
# 6  {'n_estimators': 10, 'max_samples': 0.65}
#
#        p@10  train_time
# 0  1.000000  3.223455
# 1  1.000000  0.665905
# 2  1.000000  2.242482
# 3  1.000000  5.092103
# 4  1.000000  0.660460
# 5  0.994670  0.941155
# 6  0.993147  1.022354

# %%
# precision at 5%
p_at_5_ranking = ea.get_info(ranking_dict, 'p@5', ['model','parameters','p@5', 'train_time'])
p_at_5_ranking
# Out:
#    index model  \
# 0  0      BAG
# 1  1      BST
# 2  2      DT
# 3  3      KNN
# 4  4      LR
# 5  6      RF
# 6  5      NB
#
#                                                                               parameters  \
# 0  {'n_estimators': 10, 'max_samples': 0.65}
# 1  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 2  {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 2, 'max_features': 'sqrt'}
# 3  {'n_neighbors': 10, 'weights': 'distance', 'algorithm': 'kd_tree'}
# 4  {'penalty': 'l1', 'C': 0.1}
# 5  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 6  {}
#
#         p@5  train_time
# 0  1.000000  1.022354
# 1  1.000000  49.490264
# 2  1.000000  0.665905
# 3  1.000000  2.284315
# 4  1.000000  2.067020
# 5  1.000000  0.660460
# 6  0.989644  0.941155

# %%
# precision at 2%
p_at_2_ranking = ea.get_info(ranking_dict, 'p@2', ['model','parameters','p@2', 'train_time'])
p_at_2_ranking
# Out:
#    index model  \
# 0  0      BAG
# 1  1      BST
# 2  2      DT
# 3  3      KNN
# 4  4      LR
# 5  5      NB
# 6  6      RF
#
#                                                                                parameters  \
# 0  {'n_estimators': 5, 'max_samples': 0.5}
# 1  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 2  {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'max_features': 'sqrt'}
# 3  {'n_neighbors': 10, 'weights': 'distance', 'algorithm': 'kd_tree'}
# 4  {'penalty': 'l1', 'C': 0.1}
# 5  {}
# 6  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
#
#    p@2  train_time
# 0  1.0  0.831823
# 1  1.0  49.490264
# 2  1.0  0.839643
# 3  1.0  2.284315
# 4  1.0  2.067020
# 5  1.0  0.941155
# 6  1.0  0.660460

# %%
# precision at 1%
p_at_1_ranking = ea.get_info(ranking_dict, 'p@1', ['model','parameters','p@1', 'train_time'])
p_at_1_ranking
# Out:
#    index model  \
# 0  0      BAG
# 1  1      BST
# 2  2      DT
# 3  3      KNN
# 4  4      LR
# 5  5      NB
# 6  6      RF
#
#                                                                                parameters  \
# 0  {'n_estimators': 20, 'max_samples': 0.65}
# 1  {'n_estimators': 10, 'algorithm': 'SAMME'}
# 2  {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'max_features': 'sqrt'}
# 3  {'n_neighbors': 25, 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 4  {'penalty': 'l1', 'C': 1}
# 5  {}
# 6  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
#
#    p@1  train_time
# 0  1.0  1.631213
# 1  1.0  3.223455
# 2  1.0  0.708742
# 3  1.0  2.324620
# 4  1.0  1.932698
# 5  1.0  0.941155
# 6  1.0  0.660460

# %%
# recall at 50%
r_at_50_ranking = ea.get_info(ranking_dict, 'r@50', ['model','parameters','r@50', 'train_time', 'p@50'])
r_at_50_ranking
# Out:
#    index model  \
# 0  2      DT
# 1  3      KNN
# 2  6      RF
# 3  1      BST
# 4  4      LR
# 5  0      BAG
# 6  5      NB
#
#                                                                                  parameters  \
# 0  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 5, 'max_features': 'sqrt'}
# 1  {'n_neighbors': 1, 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 2  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 3  {'n_estimators': 10, 'algorithm': 'SAMME'}
# 4  {'penalty': 'l1', 'C': 0.1}
# 5  {'n_estimators': 10, 'max_samples': 0.5}
# 6  {}
#
#        r@50  train_time      p@50
# 0  0.710657  0.624636    1.000000
# 1  0.710657  2.376567    1.000000
# 2  0.710657  0.660460    1.000000
# 3  0.683600  3.223455    0.961927
# 4  0.680852  2.067020    0.958059
# 5  0.670397  0.951025    0.943348
# 6  0.652713  0.941155    0.918464

# %%
# recall at 30%
r_at_30_ranking = ea.get_info(ranking_dict, 'r@30', ['model','parameters','r@30', 'train_time'])
r_at_30_ranking
# Out:
#    index model  \
# 0  2      DT
# 1  3      KNN
# 2  6      RF
# 3  1      BST
# 4  4      LR
# 5  5      NB
# 6  0      BAG
#
#                                                                                  parameters  \
# 0  {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 5, 'max_features': 'sqrt'}
# 1  {'n_neighbors': 1, 'weights': 'distance', 'algorithm': 'auto'}
# 2  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 3  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 4  {'penalty': 'l1', 'C': 0.1}
# 5  {}
# 6  {'n_estimators': 10, 'max_samples': 0.5}
#
#        r@30  train_time
# 0  0.426390  0.624636
# 1  0.426390  2.310801
# 2  0.426390  0.660460
# 3  0.416152  49.490264
# 4  0.415059  2.067020
# 5  0.404810  0.941155
# 6  0.396779  0.951025

# %%
# recall at 20%
r_at_20_ranking = ea.get_info(ranking_dict, 'r@20', ['model','parameters','r@20', 'train_time'])
r_at_20_ranking
# Out:
#    index model  \
# 0  2      DT
# 1  3      KNN
# 2  6      RF
# 3  4      LR
# 4  1      BST
# 5  5      NB
# 6  0      BAG
#
#                                                                                 parameters  \
# 0  {'criterion': 'gini', 'max_depth': 100, 'min_samples_split': 5, 'max_features': 'sqrt'}
# 1  {'n_neighbors': 1, 'weights': 'uniform', 'algorithm': 'auto'}
# 2  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 3  {'penalty': 'l1', 'C': 0.1}
# 4  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 5  {}
# 6  {'n_estimators': 5, 'max_samples': 0.5}
#
#        r@20  train_time
# 0  0.284256  1.126271
# 1  0.284256  2.799279
# 2  0.284256  0.660460
# 3  0.280111  2.067020
# 4  0.279116  49.490264
# 5  0.277633  0.941155
# 6  0.275782  0.831823

# %%
# recall at 10%
r_at_10_ranking = ea.get_info(ranking_dict, 'r@10', ['model','parameters','r@10', 'train_time'])
r_at_10_ranking
# Out:
#    index model  \
# 0  1      BST
# 1  2      DT
# 2  3      KNN
# 3  4      LR
# 4  6      RF
# 5  5      NB
# 6  0      BAG
#
#                                                                               parameters  \
# 0  {'n_estimators': 10, 'algorithm': 'SAMME'}
# 1  {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 2, 'max_features': 'sqrt'}
# 2  {'n_neighbors': 1, 'weights': 'distance', 'algorithm': 'kd_tree'}
# 3  {'penalty': 'l1', 'C': 10}
# 4  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 5  {}
# 6  {'n_estimators': 10, 'max_samples': 0.65}
#
#        r@10  train_time
# 0  0.142123  3.223455
# 1  0.142123  0.665905
# 2  0.142123  2.242482
# 3  0.142123  5.092103
# 4  0.142123  0.660460
# 5  0.141365  0.941155
# 6  0.141149  1.022354

# %%
# recall at 5%
r_at_5_ranking = ea.get_info(ranking_dict, 'r@5', ['model','parameters','r@5', 'train_time'])
r_at_5_ranking
# Out:
#    index model  \
# 0  0      BAG
# 1  1      BST
# 2  2      DT
# 3  3      KNN
# 4  4      LR
# 5  6      RF
# 6  5      NB
#
#                                                                               parameters  \
# 0  {'n_estimators': 10, 'max_samples': 0.65}
# 1  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 2  {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 2, 'max_features': 'sqrt'}
# 3  {'n_neighbors': 10, 'weights': 'distance', 'algorithm': 'kd_tree'}
# 4  {'penalty': 'l1', 'C': 0.1}
# 5  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
# 6  {}
#
#         r@5  train_time
# 0  0.071061  1.022354
# 1  0.071061  49.490264
# 2  0.071061  0.665905
# 3  0.071061  2.284315
# 4  0.071061  2.067020
# 5  0.071061  0.660460
# 6  0.070325  0.941155

# %%
# recall at 2%
r_at_2_ranking = ea.get_info(ranking_dict, 'r@2', ['model','parameters','r@2', 'train_time'])
r_at_2_ranking
# Out:
#    index model  \
# 0  0      BAG
# 1  1      BST
# 2  2      DT
# 3  3      KNN
# 4  4      LR
# 5  5      NB
# 6  6      RF
#
#                                                                                parameters  \
# 0  {'n_estimators': 5, 'max_samples': 0.5}
# 1  {'n_estimators': 200, 'algorithm': 'SAMME'}
# 2  {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'max_features': 'sqrt'}
# 3  {'n_neighbors': 10, 'weights': 'distance', 'algorithm': 'kd_tree'}
# 4  {'penalty': 'l1', 'C': 0.1}
# 5  {}
# 6  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
#
#        r@2  train_time
# 0  0.02842  0.831823
# 1  0.02842  49.490264
# 2  0.02842  0.839643
# 3  0.02842  2.284315
# 4  0.02842  2.067020
# 5  0.02842  0.941155
# 6  0.02842  0.660460

# %%
# recall at 1%
r_at_1_ranking = ea.get_info(ranking_dict, 'r@1', ['model','parameters','r@1', 'train_time'])
r_at_1_ranking
# Out:
#    index model  \
# 0  0      BAG
# 1  1      BST
# 2  2      DT
# 3  3      KNN
# 4  4      LR
# 5  5      NB
# 6  6      RF
#
#                                                                                parameters  \
# 0  {'n_estimators': 20, 'max_samples': 0.65}
# 1  {'n_estimators': 10, 'algorithm': 'SAMME'}
# 2  {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'max_features': 'sqrt'}
# 3  {'n_neighbors': 25, 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 4  {'penalty': 'l1', 'C': 1}
# 5  {}
# 6  {'max_features': 'sqrt', 'n_estimators': 1, 'max_depth': 1, 'min_samples_split': 2}
#
#        r@1  train_time
# 0  0.01421  1.631213
# 1  0.01421  3.223455
# 2  0.01421  0.708742
# 3  0.01421  2.324620
# 4  0.01421  1.932698
# 5  0.01421  0.941155
# 6  0.01421  0.660460
