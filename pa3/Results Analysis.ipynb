# %%
import pandas as pd
import numpy as np
import eval_analysis as ea

# %%
# display full dataframe information 
pd.set_option('display.max_colwidth', -1)

# %%
METRICS = ["train_time", "test_time", "accuracy", "F1_score", "auc", 
           "p@1","p@2","p@5","p@10","p@20","p@30","p@50",
           "r@1","r@2","r@5","r@10","r@20","r@30","r@50"]

# %%
result_df = pd.read_csv("eval_results/classifiers_eval.csv", index_col=0)

# %%
ranking_dict = ea.all_rankings(result_df, METRICS)

# %%
# training time
train_time_ranking = ea.get_info(ranking_dict, 'train_time', ['model','parameters','train_time'])
train_time_ranking
# Out:
#    index model  \
# 0  2      DT
# 1  6      RF
# 2  0      BAG
# 3  5      NB
# 4  4      LR
# 5  3      KNN
# 6  1      BST
#
#                                                                                parameters  \
# 0  {'max_depth': 1, 'criterion': 'gini', 'min_samples_split': 10, 'max_features': 'sqrt'}
# 1  {'max_depth': 1, 'min_samples_split': 2, 'n_estimators': 1, 'max_features': 'log2'}
# 2  {'n_estimators': 5, 'max_samples': 0.5}
# 3  {}
# 4  {'C': 0.01, 'penalty': 'l1'}
# 5  {'algorithm': 'kd_tree', 'weights': 'uniform', 'n_neighbors': 25}
# 6  {'algorithm': 'SAMME', 'n_estimators': 10}
#
#    train_time
# 0  0.747062
# 1  0.771065
# 2  1.032019
# 3  1.115967
# 4  2.501115
# 5  3.132684
# 6  3.989697

# %%
# testing time
test_time_ranking = ea.get_info(ranking_dict, 'test_time', ['model','parameters','test_time'])
test_time_ranking
# Out:
#    index model  \
# 0  6      RF
# 1  2      DT
# 2  4      LR
# 3  0      BAG
# 4  1      BST
# 5  5      NB
# 6  3      KNN
#
#                                                                                  parameters  \
# 0  {'max_depth': 1, 'min_samples_split': 2, 'n_estimators': 1, 'max_features': 'log2'}
# 1  {'max_depth': 1, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': 'log2'}
# 2  {'C': 0.1, 'penalty': 'l1'}
# 3  {'n_estimators': 5, 'max_samples': 0.5}
# 4  {'algorithm': 'SAMME', 'n_estimators': 10}
# 5  {}
# 6  {'algorithm': 'kd_tree', 'weights': 'uniform', 'n_neighbors': 1}
#
#    test_time
# 0  0.215229
# 1  0.219448
# 2  0.248512
# 3  0.266158
# 4  0.306303
# 5  0.431144
# 6  4.689851

# %%
# accuracy
acc_ranking = ea.get_info(ranking_dict, 'accuracy', ['model','parameters','accuracy'])
acc_ranking
# Out:
#    index model  \
# 0  6      RF
# 1  2      DT
# 2  1      BST
# 3  4      LR
# 4  5      NB
# 5  3      KNN
# 6  0      BAG
#
#                                                                                   parameters  \
# 0  {'max_depth': 50, 'min_samples_split': 10, 'n_estimators': 100, 'max_features': 'log2'}
# 1  {'max_depth': 10, 'criterion': 'entropy', 'min_samples_split': 2, 'max_features': 'sqrt'}
# 2  {'algorithm': 'SAMME', 'n_estimators': 100}
# 3  {'C': 0.01, 'penalty': 'l2'}
# 4  {}
# 5  {'algorithm': 'ball_tree', 'weights': 'distance', 'n_neighbors': 10}
# 6  {'n_estimators': 5, 'max_samples': 0.35}
#
#    accuracy
# 0  0.941578
# 1  0.924967
# 2  0.913609
# 3  0.911669
# 4  0.856185
# 5  0.767127
# 6  0.712914

# %%
# F1 score
f1_ranking = ea.get_info(ranking_dict, 'F1_score', ['model','parameters','F1_score'])
f1_ranking
# Out:
#    index model  \
# 0  6      RF
# 1  2      DT
# 2  1      BST
# 3  4      LR
# 4  5      NB
# 5  3      KNN
# 6  0      BAG
#
#                                                                                   parameters  \
# 0  {'max_depth': 50, 'min_samples_split': 10, 'n_estimators': 100, 'max_features': 'log2'}
# 1  {'max_depth': 10, 'criterion': 'entropy', 'min_samples_split': 2, 'max_features': 'sqrt'}
# 2  {'algorithm': 'SAMME', 'n_estimators': 100}
# 3  {'C': 0.01, 'penalty': 'l2'}
# 4  {}
# 5  {'algorithm': 'ball_tree', 'weights': 'distance', 'n_neighbors': 10}
# 6  {'n_estimators': 10, 'max_samples': 0.35}
#
#    F1_score
# 0  0.959939
# 1  0.948369
# 2  0.940490
# 3  0.939481
# 4  0.903468
# 5  0.851536
# 6  0.832399

# %%
# AUC-ROC
auc_ranking = ea.get_info(ranking_dict, 'auc', ['model','parameters','auc'])
auc_ranking
# Out:
#   model  \
# 6  RF
# 2  DT
# 1  BST
# 4  LR
# 5  NB
# 3  KNN
# 0  BAG
#
#                                                                                   parameters  \
# 6  {'max_depth': 50, 'min_samples_split': 10, 'n_estimators': 100, 'max_features': 'log2'}
# 2  {'max_depth': 20, 'criterion': 'entropy', 'min_samples_split': 5, 'max_features': 'log2'}
# 1  {'algorithm': 'SAMME', 'n_estimators': 200}
# 4  {'C': 0.01, 'penalty': 'l1'}
# 5  {}
# 3  {'algorithm': 'ball_tree', 'weights': 'uniform', 'n_neighbors': 1}
# 0  {'n_estimators': 10, 'max_samples': 0.35}
#
#         auc
# 6  0.911729
# 2  0.894092
# 1  0.882421
# 4  0.877199
# 5  0.791051
# 3  0.659994
# 0  0.500000

# %%
# precision at 50%
p_at_50_ranking = ea.get_info(ranking_dict, 'p@50', ['model','parameters','p@50', 'train_time'])
p_at_50_ranking
# Out:
#   model  \
# 2  DT
# 3  KNN
# 6  RF
# 1  BST
# 4  LR
# 0  BAG
# 5  NB
#
#                                                                                  parameters  \
# 2  {'max_depth': 1, 'criterion': 'entropy', 'min_samples_split': 2, 'max_features': 'sqrt'}
# 3  {'algorithm': 'kd_tree', 'weights': 'uniform', 'n_neighbors': 1}
# 6  {'max_depth': 1, 'min_samples_split': 2, 'n_estimators': 1, 'max_features': 'sqrt'}
# 1  {'algorithm': 'SAMME', 'n_estimators': 10}
# 4  {'C': 10, 'penalty': 'l1'}
# 0  {'n_estimators': 5, 'max_samples': 0.5}
# 5  {}
#
#        p@50  train_time
# 2  1.000000  0.772367
# 3  1.000000  3.340560
# 6  1.000000  0.801112
# 1  0.960401  3.989697
# 4  0.957792  2.851313
# 0  0.937595  1.032019
# 5  0.918079  1.115967

# %%
# recall at 50%
r_at_50_ranking = ea.get_info(ranking_dict, 'r@50', ['model','parameters','r@50', 'train_time'])
r_at_50_ranking
# Out:
#   model  \
# 2  DT
# 3  KNN
# 6  RF
# 1  BST
# 4  LR
# 0  BAG
# 5  NB
#
#                                                                                  parameters  \
# 2  {'max_depth': 1, 'criterion': 'entropy', 'min_samples_split': 2, 'max_features': 'sqrt'}
# 3  {'algorithm': 'kd_tree', 'weights': 'uniform', 'n_neighbors': 1}
# 6  {'max_depth': 1, 'min_samples_split': 2, 'n_estimators': 1, 'max_features': 'sqrt'}
# 1  {'algorithm': 'SAMME', 'n_estimators': 10}
# 4  {'C': 10, 'penalty': 'l1'}
# 0  {'n_estimators': 5, 'max_samples': 0.5}
# 5  {}
#
#        r@50  train_time
# 2  0.701346  0.772367
# 3  0.701346  3.340560
# 6  0.701346  0.801112
# 1  0.673574  3.989697
# 4  0.671744  2.851313
# 0  0.657579  1.032019
# 5  0.643892  1.115967
