# %%
import pandas as pd
import numpy as np
import eval_analysis as ea

# %%
pd.set_option('display.max_colwidth', -1)

# %%
METRICS = ["train_time", "test_time", "accuracy", "F1_score", "auc", 
           "p@1","p@2","p@5","p@10","p@20","p@30","p@50",
           "r@1","r@2","r@5","r@10","r@20","r@30","r@50"]

# %%
result_df = pd.read_csv("eval_results/classifiers_eval.csv", index_col=0)

# %%
ranking_dict = ea.all_rankings(result_df, METRICS)

# %%
ranking_dict['train_time']
# Out:
#   model  \
# 2  DT
# 6  RF
# 0  BAG
# 5  NB
# 4  LR
# 3  KNN
# 1  BST
#
#                                                                                parameters  \
# 2  {'max_depth': 1, 'criterion': 'gini', 'min_samples_split': 10, 'max_features': 'sqrt'}
# 6  {'max_depth': 1, 'min_samples_split': 2, 'n_estimators': 1, 'max_features': 'log2'}
# 0  {'n_estimators': 5, 'max_samples': 0.5}
# 5  {}
# 4  {'C': 0.01, 'penalty': 'l1'}
# 3  {'algorithm': 'kd_tree', 'weights': 'uniform', 'n_neighbors': 25}
# 1  {'algorithm': 'SAMME', 'n_estimators': 10}
#
#    train_time  test_time  accuracy  F1_score       auc       p@1       p@2  \
# 2  0.747062    0.230862   0.712914  0.832399  0.500000  1.000000  1.000000
# 6  0.771065    0.215229   0.712914  0.832399  0.500000  1.000000  1.000000
# 0  1.032019    0.266158   0.712914  0.832399  0.500000  0.967083  0.964813
# 5  1.115967    0.431144   0.856185  0.903468  0.791051  1.000000  1.000000
# 4  2.501115    0.315842   0.909762  0.937768  0.877199  1.000000  0.999432
# 3  3.132684    8.189633   0.747146  0.844269  0.588243  1.000000  0.940976
# 1  3.989697    0.306303   0.902648  0.932300  0.874759  1.000000  1.000000
#
#         p@5    ...         p@20      p@30      p@50       r@1       r@2  \
# 2  1.000000    ...     1.000000  0.908094  0.944857  0.014022  0.028043
# 6  1.000000    ...     1.000000  0.908094  0.944857  0.014022  0.028043
# 0  0.972310    ...     0.929196  0.899206  0.937595  0.013560  0.027056
# 5  0.992964    ...     0.977079  0.951324  0.918079  0.014022  0.028043
# 4  0.997730    ...     0.984512  0.973336  0.957247  0.014022  0.028027
# 3  0.976396    ...     0.932827  0.890809  0.857467  0.014022  0.026388
# 1  1.000000    ...     0.975037  0.974735  0.960401  0.014022  0.028043
#
#         r@5      r@10      r@20      r@30      r@50
# 2  0.070124  0.140263  0.280526  0.382130  0.662672
# 6  0.070124  0.140263  0.280526  0.382130  0.662672
# 0  0.068182  0.134183  0.260663  0.378390  0.657579
# 5  0.069630  0.139738  0.274096  0.400321  0.643892
# 4  0.069964  0.139594  0.276181  0.409584  0.671362
# 3  0.068468  0.133801  0.261682  0.374857  0.601381
# 1  0.070124  0.140263  0.273523  0.410173  0.673574
#
# [7 rows x 21 columns]

# %%
pd.set_option('display.max_colwidth', -1)

# %%
ranking_dict['train_time'][['model','parameters']]
# Out:
#   model  \
# 2  DT
# 6  RF
# 0  BAG
# 5  NB
# 4  LR
# 3  KNN
# 1  BST
#
#                                                                                parameters
# 2  {'max_depth': 1, 'criterion': 'gini', 'min_samples_split': 10, 'max_features': 'sqrt'}
# 6  {'max_depth': 1, 'min_samples_split': 2, 'n_estimators': 1, 'max_features': 'log2'}
# 0  {'n_estimators': 5, 'max_samples': 0.5}
# 5  {}
# 4  {'C': 0.01, 'penalty': 'l1'}
# 3  {'algorithm': 'kd_tree', 'weights': 'uniform', 'n_neighbors': 25}
# 1  {'algorithm': 'SAMME', 'n_estimators': 10}
